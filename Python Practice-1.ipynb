# %% [markdown]
# # 🐍 Python Practice Question Bank
# ### Beginner Level | Variables · Data Types · Operators · Strings · Indexing · Slicing
# ---
# > **Instructions:**
# > - 🖊️ **Code Writing** — Write Python code in the empty cell below each question.
# > - 🔍 **Predict the Output** — Read the code carefully, write your expected output as comments, then run.
# > - Do **not** use built-in methods unless the question allows it.
# > - All questions are compatible with **Python 3**.

# %% [markdown]
# ---
# ---
# ## 📘 Section 1: Variables & Data Types
# ### *(20 Questions — 16 Code Writing | 4 Predict Output)*

# %% [markdown]
# ---
#
# **Q1. 🖊️ Code Writing**
#
# Create four variables:
# - `name` storing your name as a string
# - `age` storing your age as an integer
# - `height` storing your height in cm as a float
# - `is_employed` storing `False` as a boolean
#
# Print all four variables on separate lines.

# %%
# Write your code here
name = "Soumya Ranjan Das"
age = 21
height = 180.5
is_employed = False
print(name)
print(age)
print(height)
print(is_employed)
# Out:
# Soumya Ranjan Das
# 21
# 180.5
# False

# %% [markdown]
# ---
#
# **Q2. 🖊️ Code Writing**
#
# Create a variable `city = "Bhubaneswar"`.
# - Print the variable
# - Print its data type using `type()`

# %%
city = "Bhubaneswar"
print(city)
print(type(city))# Write your code here
# Out:
# Bhubaneswar
# <class 'str'>

# %% [markdown]
# ---
#
# **Q3. 🖊️ Code Writing**
#
# Store the value `3 + 4j` in a variable `z`. Print:
# - The variable `z`
# - Its data type
# - Its real part
# - Its imaginary part

# %%
z = 3+4j
print(z)
print(type(z))
print(

# %% [markdown]
# ---
#
# **Q4. 🖊️ Code Writing**
#
# Assign the same value `100` to three variables `x`, `y`, and `z` using a **single line** of code.
# Print all three.

# %%
# Write your code here
x=y=z=100
print(x)
print(y)
print(z)
# Out:
# 100
# 100
# 100

# %% [markdown]
# ---
#
# **Q5. 🖊️ Code Writing**
#
# Create two variables `a = 50` and `b = 75`.
# Swap their values **without using a third variable**.
# Print `a` and `b` after swapping.

# %%
# Write your code here
a=50
b=75
a,b=b,a
print(a)
print(b)
# Out:
# 75
# 50

# %% [markdown]
# ---
#
# **Q6. 🖊️ Code Writing**
#
# Create variables of all five data types: `int`, `float`, `str`, `bool`, and `complex`.
# Print each variable along with its type in this format:
# ```
# Value: 10  |  Type: <class 'int'>
# ```

# %%
# Write your code here
num=10
price=99.99
name="Soumya"
is_person = True
z=3+4j
print(type(num))
print(type(price))
print(type(name))
print(type(is_person))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %% [markdown]
# ---
#
# **Q7. 🖊️ Code Writing**
#
# Demonstrate **type conversion**:
# - Convert the integer `42` to a float and print it
# - Convert the float `9.99` to an integer and print it
# - Convert the integer `100` to a string and print it with its type

# %%
# Write your code here
num = 42
float_num = float(num)
print(float_num)
price=9.99
int_price = int(price)
print(int_price)
number = 100
str_number = str(number)
print(str_number)
print(type(str_number))
# Out:
# 42.0
# 9
# 100
# <class 'str'>

# %% [markdown]
# ---
#
# **Q8. 🖊️ Code Writing**
#
# Create two variables: `p = "25"` and `q = "30"`.
# - First print `p + q` (string concatenation)
# - Then convert both to integers and print their sum
#
# Observe the difference.

# %%
# Write your code here
p = "25"
q = "30"
print(p+q)
print(int(p) + int(q))
# Out:
# 2530
# 55

# %% [markdown]
# ---
#
# **Q9. 🖊️ Code Writing**
#
# Create a variable `flag = True`.
# - Print `flag`
# - Print `flag + 1`
# - Print `flag * 10`
# - Print the type of `flag`

# %%
# Write your code here
flag = True
print(flag)
print(flag+1)
print(flag*10)
print(type(flag))
# Out:
# True
# 2
# 10
# <class 'bool'>

# %% [markdown]
# ---
#
# **Q10. 🖊️ Code Writing**
#
# Write code to create a student profile using five variables:
# `roll_no`, `student_name`, `percentage`, `passed`, `grade`
#
# Assign appropriate values and data types to each.
# Print all five on separate lines.

# %%
# Write your code here
roll_no = 1
student_name = "Soumya"
percentage = 68.8
passed = True
grade = "A"

print(type(roll_no))
print(type(student_name))
print(type(percentage))
print(type(passed))
print(type(grade))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ---
#
# **Q11. 🔍 Predict the Output**
#
# ```python
# x = 10
# y = 3.0
# z = x + y
# print(z)
# print(type(z))
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
x = 10 
y = 3.0
z = x + y
print(z)
print(type(z))
# Out:
# 13.0
# <class 'float'>

# %% [markdown]
# ---
#
# **Q12. 🖊️ Code Writing**
#
# Create two variables `first_name = "Amit"` and `last_name = "Sharma"`.
# Join them with a space and store in `full_name`.
# Print `full_name`.

# %%
# Write your code here
first_name = "Amit"
last_name = "Sharma"
full_name = first_name+" "+last_name
print(full_name)
# Out:
# Amit Sharma

# %% [markdown]
# ---
#
# **Q13. 🖊️ Code Writing**
#
# A product has the following details:
# - Product name: `"Laptop"`
# - Price: `55999.99`
# - In Stock: `True`
# - Units Available: `15`
#
# Store each in an appropriately named variable and print all details.

# %%
# Write your code here
product_name = "Laptop"
price = 55999.99
in_stock = True
units_available = 15
print("Product Name:",product_name)
print("Price:",price)
print("In Stock:",in_stock)
print("Units Available:",units_available)
# Out:
# Product Name: Laptop
# Price: 55999.99
# In Stock: True
# Units Available: 15

# %% [markdown]
# ---
#
# **Q14. 🔍 Predict the Output**
#
# ```python
# a = True
# b = False
# print(a + b)
# print(a * 5)
# print(b + 10)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
a = True
b = False
print(a + b)
print(a * 5)
print(b + 10)
# Out:
# 1
# 5
# 10

# %% [markdown]
# ---
#
# **Q15. 🖊️ Code Writing**
#
# Create a variable `score = 95.5`.
# - Print the type of `score`
# - Convert it to `int` and print the result
# - Convert it to `str` and print the type of the result

# %%
# Write your code here
score = 95.5
print(type(score))
score_int=int(score)
print(score_int)
score_str = str(score)
print(score_str)
print(type(score_str))
# Out:
# <class 'float'>
# 95
# 95.5
# <class 'str'>

# %% [markdown]
# ---
#
# **Q16. 🖊️ Code Writing**
#
# Show Python is **dynamically typed**:
# - Assign `x = 10` (integer) and print its type
# - Reassign `x = "Python"` (string) and print its type
# - Reassign `x = 3.14` (float) and print its type

# %%
# Write your code here
x = 10
print(type(x))

x = "Python"
print(type(x))

x=3.14
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ---
#
# **Q17. 🖊️ Code Writing**
#
# Create three variables in a single line:
# ```
# a = 5, b = 10, c = 15
# ```
# using Python's multiple assignment feature. Print all three.

# %%
# Write your code here
a = 5
b = 10 
c = 15
print(a)
print(b)
print(c)
# Out:
# 5
# 10
# 15

# %% [markdown]
# ---
#
# **Q18. 🔍 Predict the Output**
#
# ```python
# x = "5"
# y = 5
# print(x == y)
# print(type(x) == type(y))
# print(int(x) == y)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1 false
# Line 2: true
# Line 3: False

x = "5"
y = 5
print(x == y)
print(type(x) == type(y))
print(int(x) == y)
# Out:
# False
# False
# True

# %% [markdown]
# ---
#
# **Q19. 🖊️ Code Writing**
#
# An employee record has:
# - `emp_id = 1042` (int)
# - `emp_name = "Rekha Nair"` (str)
# - `salary = 48500.75` (float)
# - `is_active = True` (bool)
#
# Print each field with a label, like:
# ```
# Employee ID: 1042
# Name: Rekha Nair
# ```

# %%
# Write your code her
emp_id = 1042
emp_name = "Rekha Nair"
salary = 48500.75
is_active = True
print("Employee Name:",emp_name)
print("Employee ID:",emp_id)
print("Salary:",salary)
print("Is Active:",is_active)
# Out:
# Employee Name: Rekha Nair
# Employee ID: 1042
# Salary: 48500.75
# Is Active: True

# %% [markdown]
# ---
#
# **Q20. 🔍 Predict the Output**
#
# ```python
# x = 100
# y = x
# x = 200
# print(x)
# print(y)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
x = 100
y = x
x = 200
print(x)
print(y)
# Out:
# 200
# 100

# %% [markdown]
# ---
# ---
# ## 📗 Section 2: Arithmetic Operators
# ### *(20 Questions — 16 Code Writing | 4 Predict Output)*

# %% [markdown]
# ---
#
# **Q21. 🖊️ Code Writing**
#
# Store `a = 27` and `b = 4`.
# Print the result of all arithmetic operations: `+`, `-`, `*`, `/`, `//`, `%`, `**`.
# Add a comment next to each line explaining what it does.

# %%
# Write your code here
a = 27
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 31
# 23
# 108
# 6.75
# 6
# 3
# 531441

# %% [markdown]
# ---
#
# **Q22. 🖊️ Code Writing**
#
# A rectangle has `length = 12` and `breadth = 7`. Calculate and print:
# - **Perimeter** = `2 * (length + breadth)`
# - **Area** = `length * breadth`

# %%
# Write your code here
length = 12
breadth = 7 
perimeter = 2 * (length + breadth)
area = length * breadth
print("Parameter=",perimeter)
print("Area=",area)
# Out:
# Parameter= 38
# Area= 84

# %% [markdown]
# ---
#
# **Q23. 🖊️ Code Writing**
#
# A student scored marks in 5 subjects: `85, 90, 78, 92, 88`.
# Store them in 5 separate variables.
# Calculate and print the **total** and **average**.

# %%
# Write your code here
subject1 = 85
subject2=90
subject3=78
subject4=92
subject5=88
total = subject1+subject2+subject3+subject4+subject5
average = total/5

print("Total Marks=",total)
print("Average Marks=",average)
# Out:
# Total Marks= 433
# Average Marks= 86.6

# %% [markdown]
# ---
#
# **Q24. 🖊️ Code Writing**
#
# Write code to check if the number `128` is **even or odd** using the modulus operator.
# Store the result of `128 % 2` in a variable and print it.
# Add a comment explaining what the result means.

# %%
# Write your code here
number = 128
result = 128 %2
print(result)
# Out:
# 0

# %% [markdown]
# ---
#
# **Q25. 🖊️ Code Writing**
#
# A box contains `250` chocolates to be divided equally among `12` children.
# Using floor division and modulus:
# - Print how many chocolates **each child gets**
# - Print how many chocolates are **left over**

# %%
# Write your code here
chocolate = 250
children = 12
each_child = chocolate//children
left_chocolate = chocolate%children
print(each_child)
print(left_chocolate)
# Out:
# 20
# 10

# %% [markdown]
# ---
#
# **Q26. 🖊️ Code Writing**
#
# Calculate the following using Python:
# - 2 raised to the power 8
# - Square root of 144 (using `** 0.5`)
# - Cube of 7
#
# Print all three results.

# %%
# Write your code here
power = 2**8
square_root = 144**0.5
cube= 7**3
print(power)
print(cube)
print(square_root)
# Out:
# 256
# 343
# 12.0

# %% [markdown]
# ---
#
# **Q27. 🖊️ Code Writing**
#
# Temperature conversion:
# Given `celsius = 37`, convert it to Fahrenheit.
# Formula: `F = (C * 9/5) + 32`
# Print the result.

# %%
# Write your code here
celsius = 37
fahrenheit =  (celsius * 9/5) + 32
print("Fahrenheit=",fahrenheit)
# Out:
# Fahrenheit= 98.6

# %% [markdown]
# ---
#
# **Q28. 🔍 Predict the Output**
#
# ```python
# x = 17
# y = 5
# print(x / y)
# print(x // y)
# print(x % y)
# print(x ** 2)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
x = 17
y = 5
print(x / y)
print(x // y)
print(x % y)
print(x ** 2)
# Out:
# 3.4
# 3
# 2
# 289

# %% [markdown]
# ---
#
# **Q29. 🖊️ Code Writing**
#
# A shop sells pens at ₹8 each. A customer buys `37` pens.
# - Calculate the **total cost**
# - The customer pays ₹300 — calculate the **change** to be returned

# %%
# Write your code here
pen_cost = 8
buys = 37
total_cost = pen_cost*buys
amount_paid = 300 
return_cost = amount_paid - total_cost
print("Total cost=",total_cost)
print("Change Return=", return_cost)
# Out:
# Total cost= 296
# Change Return= 4

# %% [markdown]
# ---
#
# **Q30. 🖊️ Code Writing**
#
# Verify the **Pythagorean theorem** for `a = 3`, `b = 4`, `c = 5`.
# Calculate `a**2 + b**2` and `c**2` and print both.
# Are they equal?

# %%
# Write your code here
a=3 
b=4
c=5
print(a**2+b**2)
print(c**2)
# Out:
# 25
# 25

# %% [markdown]
# ---
#
# **Q31. 🖊️ Code Writing**
#
# A train travels at `speed = 90` km/h for `distance = 450` km.
# Calculate and print the **time** required.
# Formula: `time = distance / speed`

# %%
# Write your code here
speed = 90
distance = 450
time = distance/speed
print(time)
# Out:
# 5.0

# %% [markdown]
# ---
#
# **Q32. 🖊️ Code Writing**
#
# Given `n = 365`:
# - Find the number of **complete weeks** (using `//`)
# - Find the number of **remaining days** (using `%`)

# %%
# Write your code here
n=365
print(n//7)
print(n%7)
# Out:
# 52
# 1

# %% [markdown]
# ---
#
# **Q33. 🔍 Predict the Output**
#
# ```python
# print(10 // 3)
# print(-10 // 3)
# print(10 // -3)
# print(-10 // -3)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
print(10 // 3)
print(-10 // 3)
print(10 // -3)
print(-10 // -3)
# Out:
# 3
# -4
# -4
# 3

# %% [markdown]
# ---
#
# **Q34. 🖊️ Code Writing**
#
# Simple Interest Calculation:
# - `principal = 5000`, `rate = 8`, `time = 3`
#
# Formula: `SI = (principal * rate * time) / 100`
#
# Calculate and print both the **Simple Interest** and the **Total Amount** (principal + SI).

# %%
# Write your code here
principal = 5000
rate = 8
time = 3
SI = (principal * rate * time) / 100
print("SI=",SI)
total_amount = SI + principal
print("Total Amount=",total_amount)
# Out:
# SI= 1200.0
# Total Amount= 6200.0

# %% [markdown]
# ---
#
# **Q35. 🖊️ Code Writing**
#
# Find the **last digit** of the number `9876` using the modulus operator.
# Find the **second-last digit** of the same number.
# Print both.

# %%
# Write your code here
number = 9876
second_last_number = (number//10)%10
print(second_last_number)
# Out:
# 7

# %% [markdown]
# ---
#
# **Q36. 🖊️ Code Writing**
#
# A parking lot charges ₹20 for the first hour and ₹10 for every additional hour.
# `total_hours = 5`
#
# Calculate and print the total parking fee.

# %%
# Write your code here
total_hour = 5
parking_fee = 20 + (total_hour-1)*10
print("Total Parking Fee=",parking_fee)
# Out:
# Total Parking Fee= 60

# %% [markdown]
# ---
#
# **Q37. 🔍 Predict the Output**
#
# ```python
# a = 2
# b = 3
# c = 4
# print(a + b * c)
# print((a + b) * c)
# print(a ** b ** 2)
# print((a ** b) ** 2)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
a = 2
b = 3
c = 4
print(a + b * c)
print((a + b) * c)
print(a ** b ** 2)
print((a ** b) ** 2)
# Out:
# 14
# 20
# 512
# 64

# %% [markdown]
# ---
#
# **Q38. 🖊️ Code Writing**
#
# Calculate the **digit sum** of the 4-digit number `1234`:
# - Extract each digit using `//` and `%`
# - Add them and print the digit sum
#
# *(Hint: units = n%10, tens = n//10%10, hundreds = n//100%10, thousands = n//1000)*

# %%
# Write your code here
n =1234
units = n%10
tens = n//10%10
hundreds = n//100%10
thousands = n//1000
digit_sum = units+tens+hundreds+thousands
print("Digit Sum=",digit_sum)
# Out:
# Digit Sum= 10

# %% [markdown]
# ---
#
# **Q39. 🖊️ Code Writing**
#
# A class has `total_students = 47` split into groups of `5`.
# - Print the number of **complete groups**
# - Print the number of **students left** without a complete group

# %%
# Write your code here
total_students = 47
group = 5
complete_groups = total_students//group
students_left = total_students%group
print("Complete Groups=",complete_groups)
print("Students Left=",students_left)
# Out:
# Complete Groups= 9
# Students Left= 2

# %% [markdown]
# ---
#
# **Q40. 🔍 Predict the Output**
#
# ```python
# a = 3
# b = 4
# c = 5
# print(a ** 2 + b ** 2 == c ** 2)
# print(2 + 3 * 4 - 1)
# print(10 % 3 + 7 // 2)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
a = 3
b = 4
c = 5
print(a ** 2 + b ** 2 == c ** 2)
print(2 + 3 * 4 - 1)
print(10 % 3 + 7 // 2)
# Out:
# True
# 13
# 4

# %% [markdown]
# ---
# ---
# ## 📙 Section 3: Comparison & Logical Operators
# ### *(15 Questions — 12 Code Writing | 3 Predict Output)*

# %% [markdown]
# ---
#
# **Q41. 🖊️ Code Writing**
#
# Store `a = 45` and `b = 78`.
# Write code to check and print the result of all **6 comparison operators**: `>`, `<`, `==`, `!=`, `>=`, `<=`.
# Label each result clearly.

# %%
# Write your code here
a = 45
b = 78
print("a > b :", a > b)
print("a < b :", a < b)
print("a == b:", a == b)
print("a != b:", a != b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)
# Out:
# a > b : False
# a < b : True
# a == b: False
# a != b: True
# a >= b: False
# a <= b: True

# %% [markdown]
# ---
#
# **Q42. 🖊️ Code Writing**
#
# A student needs **at least 40 marks** to pass. `marks = 38`
#
# Use a comparison operator to check if the student passed.
# Store the result in `passed` and print it.

# %%
# Write your code here
marks = 38
passed = marks>=40
print(passed)
# Out:
# False

# %% [markdown]
# ---
#
# **Q43. 🖊️ Code Writing**
#
# Check if `n = 55` lies **between 50 and 100** (inclusive).
# Use a single expression with the `and` operator and print the result.

# %%
# Write your code here
n = 55
print(n>=50 and n<=100)
# Out:
# True

# %% [markdown]
# ---
#
# **Q44. 🖊️ Code Writing**
#
# A movie ticket gives discount if age is **below 12 OR above 60**. `age = 65`
#
# Write code to check eligibility. Store the result in `is_eligible` and print it.

# %%
# Write your code here
age = 65
is_eligible = (age <12 or age >60)
print(is_eligible)
# Out:
# True

# %% [markdown]
# ---
#
# **Q45. 🖊️ Code Writing**
#
# A login system checks: `username == "admin"` AND `password == "secure123"`
#
# Set the variables and write code to check if login is successful. Print the result.

# %%
# Write your code here
username = "admin"
password = "secure123"
login_sucess =(username == "admin") and(password == "secure123")
print(login_sucess)
# Out:
# True

# %% [markdown]
# ---
#
# **Q46. 🖊️ Code Writing**
#
# `year = 2024`
#
# Use the modulus and comparison operator to check if it is divisible by 4.
# Print the boolean result.

# %%
# Write your code here
year=2024
print(year%4==0)
# Out:
# True

# %% [markdown]
# ---
#
# **Q47. 🔍 Predict the Output**
#
# ```python
# x = 10
# y = 20
# z = 10
# print(x == z)
# print(x != y)
# print(x > y or x == z)
# print(x < y and y > z)
# print(not (x == y))
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
x = 10
y = 20
z = 10
print(x == z)
print(x != y)
print(x > y or x == z)
print(x < y and y > z)
print(not (x == y))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# ---
#
# **Q48. 🖊️ Code Writing**
#
# An airline allows baggage if weight ≤ 20 kg OR the passenger has premium membership.
# `weight = 25`, `is_premium = True`
#
# Write code and print whether baggage is allowed.

# %%
# Write your code here
weight=25
is_premium=True
baggeg_allow=(weight<=20) or is_premium
print(baggeg_allow)
# Out:
# True

# %% [markdown]
# ---
#
# **Q49. 🖊️ Code Writing**
#
# A bank account requires balance > 1000 AND `is_active = True`.
# `balance = 850`, `is_active = True`
#
# Check if the account meets both conditions. Print the result.

# %%
# Write your code here
is_active=True
balance=850
bank_valid=(balance>1000) and is_active
print(bank_valid)
# Out:
# False

# %% [markdown]
# ---
#
# **Q50. 🖊️ Code Writing**
#
# Using the `not` operator, write code to:
# - Check that `x = 7` is **not** greater than 10
# - Check that `name = "Ravi"` is **not** equal to `"Raj"`
#
# Print both results.

# %%
# Write your code here
x=7
name="Ravi"
print(not(x>10))
print(not(name=="Raj"))
# Out:
# True
# True

# %% [markdown]
# ---
#
# **Q51. 🖊️ Code Writing**
#
# A scholarship is awarded if:
# - Marks > 85 AND attendance >= 90, **OR**
# - The student is from a reserved category (`reserved = True`)
#
# `marks = 80`, `attendance = 95`, `reserved = False`
#
# Write code to check and print the result.

# %%
# Write your code here
reserved = False
marks = 80
attendance = 95
scholarship=(marks >85 and attendance>=90) or reserved
print(scholarship)
# Out:
# False

# %% [markdown]
# ---
#
# **Q52. 🔍 Predict the Output**
#
# ```python
# a = True
# b = False
# c = True
# print(a and b)
# print(a or b)
# print(not a)
# print(a and b or c)
# print(not (a or b))
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
a = True
b = False
c = True
print(a and b)
print(a or b)
print(not a)
print(a and b or c)
print(not (a or b))
# Out:
# False
# True
# False
# True
# False

# %% [markdown]
# ---
#
# **Q53. 🖊️ Code Writing**
#
# Write code to check if `n = 72` is:
# - Divisible by **both 3 and 4** (use `and`)
# - Divisible by **3 or 4** (use `or`)
#
# Print both results with labels.

# %%
# Write your code here
n=72
print(n%3==0 and n%4==0)
print(n%3==0 or n%4==0)
# Out:
# True
# True

# %% [markdown]
# ---
#
# **Q54. 🖊️ Code Writing**
#
# A voting system allows voting if: age >= 18 AND is_citizen = True AND is_registered = True
#
# `age = 20`, `is_citizen = True`, `is_registered = False`
#
# Write code to check and print whether the person can vote.

# %%
# Write your code here
age = 20
is_citizen = True
is_registered = False

vote = (age >= 18) and is_citizen and is_registered

print(vote)
# Out:
# False

# %% [markdown]
# ---
#
# **Q55. 🔍 Predict the Output**
#
# ```python
# x = 5
# print(x > 3 and x < 10)
# print(x > 3 and x > 10)
# print(x < 3 or x < 10)
# print(not x > 3)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
x = 5
print(x > 3 and x < 10)
print(x > 3 and x > 10)
print(x < 3 or x < 10)
print(not x > 3)
# Out:
# True
# False
# True
# False

# %% [markdown]
# ---
# ---
# ## 📔 Section 4: Membership Operators
# ### *(10 Questions — 8 Code Writing | 2 Predict Output)*

# %% [markdown]
# ---
#
# **Q56. 🖊️ Code Writing**
#
# Create a list: `fruits = ["apple", "banana", "mango", "orange", "grape"]`
#
# Write code to:
# - Check if `"mango"` is in the list
# - Check if `"kiwi"` is NOT in the list
#
# Print both results.

# %%
# Write your code here
fruits = ["apple", "banana", "mango", "orange", "grape"]
print("mango" in fruits)
print("kiwi" in fruits)
# Out:
# True
# False

# %% [markdown]
# ---
#
# **Q57. 🖊️ Code Writing**
#
# Create a list of allowed users: `["alice", "bob", "charlie", "david"]`
# `current_user = "eve"`
#
# Write code to check if `current_user` is allowed access. Print the result.

# %%
# Write your code here
allowed_user = ["alice", "bob", "charlie", "david"]
current_user="eve"
is_allowed=current_user in allowed_user
print(is_allowed)
# Out:
# False

# %% [markdown]
# ---
#
# **Q58. 🖊️ Code Writing**
#
# `sentence = "Python is a powerful language"`
#
# Write code to check:
# - Is the word `"powerful"` in the sentence?
# - Is the word `"weak"` NOT in the sentence?

# %%
# Write your code here
sentence = "Python is a powerful language"
is_word="powerful" in sentence
print(is_word)
not_word="weak" not in sentence
print(not_word)
# Out:
# True
# True

# %% [markdown]
# ---
#
# **Q59. 🔍 Predict the Output**
#
# ```python
# data = [1, "hello", 3.14, True, None]
# print(True in data)
# print(1 in data)
# print(False in data)
# print(None in data)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
data = [1, "hello", 3.14, True, None]
print("line 1:",True in data)
print("line 2:",1 in data)
print("line 3:",False in data)
print("line 4:",None in data)
# Out:
# line 1: True
# line 2: True
# line 3: False
# line 4: True

# %% [markdown]
# ---
#
# **Q60. 🖊️ Code Writing**
#
# Create a list: `vowels = ["a", "e", "i", "o", "u"]`
#
# Write code to check whether each of the following is a vowel: `"a"`, `"b"`, `"e"`, `"z"`
# Print each result with a label.

# %%
# Write your code here
vowels = ["a", "e", "i", "o", "u"]
print("a is a vowel:","a" in vowels)
print("b is a vowel:","b" in vowels)
print("e is a vowel:","e" in vowels)
print("z is a vowel:","z" in vowels)
# Out:
# a is a vowel: True
# b is a vowel: False
# e is a vowel: True
# z is a vowel: False

# %% [markdown]
# ---
#
# **Q61. 🖊️ Code Writing**
#
# A store has: `["pen", "notebook", "eraser", "stapler", "ruler"]`
#
# A customer asks for `"compass"`.
# Write code to check if the product is available and print the result.

# %%
# Write your code here
products=["pen", "notebook", "eraser", "stapler", "ruler"]
customer_need="compass"
print("Product Available:","compass" in products)
# Out:
# Product Available: False

# %% [markdown]
# ---
#
# **Q62. 🖊️ Code Writing**
#
# `prime_numbers = (2, 3, 5, 7, 11, 13, 17, 19)`
#
# Check if the following numbers are prime using `in`: `4`, `7`, `15`, `13`
# Print each result.

# %%
# Write your code here
prime_numbers = (2, 3, 5, 7, 11, 13, 17, 19)
print("4 using:",4 in prime_numbers)
print("7 using:",7 in prime_numbers)
print("15 using:",15 in prime_numbers)
print("13 using:",13 in prime_numbers)
# Out:
# 4 using: False
# 7 using: True
# 15 using: False
# 13 using: True

# %% [markdown]
# ---
#
# **Q63. 🖊️ Code Writing**
#
# Blocked email domains: `["spam.com", "trash.net", "junk.org"]`
# `email = "user@spam.com"`
#
# Use the membership operator to check if `"spam.com"` is in the blocked list.
# Print whether the email should be blocked.

# %%
# Write your code here
blocked_domains = ["spam.com", "trash.net", "junk.org"]
email = "user@spam.com"

is_blocked = "spam.com" in blocked_domains

print("Email should be blocked:", is_blocked)
# Out:
# Email should be blocked: True

# %% [markdown]
# ---
#
# **Q64. 🔍 Predict the Output**
#
# ```python
# nums = [2, 4, 6, 8, 10]
# print(5 in nums)
# print(6 in nums)
# print(3 not in nums)
# print(10 not in nums)
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
nums = [2, 4, 6, 8, 10]
print("line 1",5 in nums)
print("line 2",6 in nums)
print("line 3",3 not in nums)
print("line 4",10 not in nums)
# Out:
# line 1 False
# line 2 True
# line 3 True
# line 4 False

# %% [markdown]
# ---
#
# **Q65. 🖊️ Code Writing**
#
# `email = "trainer@python.org"`
#
# Using membership operator, check:
# - Does the email contain `"@"`?
# - Does it contain `"gmail"`?
# - Does it NOT contain `"yahoo"`?
#
# Print all three results.

# %%
# Write your code here
email = "trainer@python.org"
print("@" in email)
print("gmail" in email)
print("yahoo" in email)
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ---
# ## 📒 Section 5: String Indexing
# ### *(15 Questions — 12 Code Writing | 3 Predict Output)*

# %% [markdown]
# ---
#
# **Q66. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Using **positive indexing**, print:
# - The first character
# - The third character
# - The last character (using positive index)

# %%
# Write your code here
s = "PYTHON"
print("The first character:",s[0])
print("The third character:",s[2])
print("The last character:",s[5])
# Out:
# The first character: P
# The third character: T
# The last character: N

# %% [markdown]
# ---
#
# **Q67. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Using **negative indexing**, print:
# - The last character
# - The second-last character
# - The first character (using negative index)

# %%
# Write your code here
s = "PYTHON"
print("The last character:",s[-1])
print("The second-last character:",s[-2])
print("The first character:",s[-6])
# Out:
# The last character: N
# The second-last character: O
# The first character: P

# %% [markdown]
# ---
#
# **Q68. 🖊️ Code Writing**
#
# `name = "Sunita Rao"`
#
# Use indexing to print:
# - The first character of the first name
# - The first character of the last name *(last name starts at index 7)*

# %%
# Write your code here
name = "Sunita Rao"
print("The first character of the first name:",name[0])
print("The first character of the last name:",name[7])
# Out:
# The first character of the first name: S
# The first character of the last name: R

# %% [markdown]
# ---
#
# **Q69. 🖊️ Code Writing**
#
# `email = "ravi@gmail.com"`
#
# Use indexing to:
# - Print the character at position `4` (the `@` symbol)
# - Print the last character

# %%
# Write your code here
email = "ravi@gmail.com"
print(email[4])
print(email[-1])
# Out:
# @
# m

# %% [markdown]
# ---
#
# **Q70. 🔍 Predict the Output**
#
# ```python
# s = "DataScience"
# print(s[0])
# print(s[4])
# print(s[-1])
# print(s[-7])
# print(len(s))
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
s = "DataScience"
print("line 1:",s[0])
print("line 2:",s[4])
print("line 3:",s[-1])
print("line 4:",s[-7])
print(len(s))
# Out:
# line 1: D
# line 2: S
# line 3: e
# line 4: S
# 11

# %% [markdown]
# ---
#
# **Q71. 🖊️ Code Writing**
#
# `word = "INTERVIEW"`
#
# Write code to:
# - Print the first character
# - Print the middle character *(index 4)*
# - Print the last character using a **negative index**

# %%
# Write your code here
word = "INTERVIEW"
print(word[0])
print(word[4])
print(word[-1])
# Out:
# I
# R
# W

# %% [markdown]
# ---
#
# **Q72. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"` (10 characters)
#
# Write code to:
# - Print the character at index `0`
# - Print the character at index `9`
# - Verify that `s[0]` and `s[-10]` print the same character

# %%
# Write your code here
s = "ABCDEFGHIJ"
print(s[0])
print(s[9])
print(s[-10])
# Out:
# A
# J
# A

# %% [markdown]
# ---
#
# **Q73. 🖊️ Code Writing**
#
# `phone = "9876543210"`
#
# Use indexing to:
# - Print the **first digit**
# - Print the **last digit**
# - Print the **5th digit** (index 4)

# %%
# Write your code here
phone = "9876543210"
print(phone[0])
print(phone[-1])
print(phone[4])
# Out:
# 9
# 0
# 5

# %% [markdown]
# ---
#
# **Q74. 🖊️ Code Writing**
#
# `product_code = "PRD-2024-XZ9"`
#
# Use indexing to:
# - Print the character at index `0`
# - Print the character at index `4`
# - Print the last character using negative indexing

# %%
# Write your code here
product_code = "PRD-2024-XZ9"
print(product_code[0])
print(product_code[4])
print(product_code[-1])
# Out:
# P
# 2
# 9

# %% [markdown]
# ---
#
# **Q75. 🖊️ Code Writing**
#
# `s = "Programming"`
#
# Write code to:
# - Find and print the **length** of the string using `len()`
# - Print the character at the **last valid positive index**

# %%
# Write your code here
s = "Programming"
print(len(s))
print(s[10])
# Out:
# 11
# g

# %% [markdown]
# ---
#
# **Q76. 🔍 Predict the Output**
#
# ```python
# s = "Hello World"
# print(s[0])
# print(s[6])
# print(s[-1])
# print(s[-5])
# print(s[len(s)-1])
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
s = "Hello World"
print("line 1:",s[0])
print("line 2:",s[6])
print("line 3:",s[-1])
print("line 4:",s[-5])
print("line 5:",s[len(s)-1])
# Out:
# line 1: H
# line 2: W
# line 3: d
# line 4: W
# line 5: d

# %% [markdown]
# ---
#
# **Q77. 🖊️ Code Writing**
#
# `roll = "2024CSIT0087"`
#
# Use indexing to:
# - Print the first character of the roll *(index 0)*
# - Print the first character of the roll *(index 4)*
# - Print the last character *(negative index)*

# %%
# Write your code here
roll = "2024CSIT0087"
print(roll[0])
print(roll[4])
print(roll[-1])
# Out:
# 2
# C
# 7

# %% [markdown]
# ---
#
# **Q78. 🖊️ Code Writing**
#
# `s = "Python"`
#
# Using `len()` and indexing, print:
# - The **middle-left character** *(index: length // 2 - 1)*
# - The **middle-right character** *(index: length // 2)*

# %%
# Write your code here
s = "Python"
length=len(s)
print(s[length // 2 - 1])
print(s[length // 2])
# Out:
# t
# h

# %% [markdown]
# ---
#
# **Q79. 🖊️ Code Writing**
#
# `barcode = "8901030408947"`
#
# Use indexing to:
# - Print the first character
# - Print the character at index `6`
# - Print the last character using a negative index

# %%
# Write your code here
barcode = "8901030408947"
print(barcode[0])
print(barcode[6])
print(barcode[-1])
# Out:
# 8
# 0
# 7

# %% [markdown]
# ---
#
# **Q80. 🔍 Predict the Output**
#
# ```python
# s = "PYTHON"
# print(s[0] == s[-6])
# print(s[5] == s[-1])
# print(s[2] == s[-4])
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
s = "PYTHON"
print("line 1:",s[0] == s[-6])
print("line 2:",s[5] == s[-1])
print("line 3 :",s[2] == s[-4])
# Out:
# line 1: True
# line 2: True
# line 3 : True

# %% [markdown]
# ---
# ---
# ## 📕 Section 6: String Slicing
# ### *(20 Questions — 17 Code Writing | 3 Predict Output)*

# %% [markdown]
# ---
#
# **Q81. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Slice and print:
# - The first 3 characters
# - The last 3 characters
# - Characters from index 2 to 5

# %%
# Write your code here
s = "PYTHON"
print(s[:3])
print(s[-3:])
print(s[2:6])
# Out:
# PYT
# HON
# THON

# %% [markdown]
# ---
#
# **Q82. 🖊️ Code Writing**
#
# `s = "PROGRAMMING"`
#
# Use and print:
# - `s[:4]`
# - `s[7:]`
# - `s[:]`
#
# Add a comment for each explaining what it does.

# %%
# Write your code here
s = "PROGRAMMING"
print(s[:4]) #Starts from index 0 and goes up to 3.
print(s[7:]) #Starts from index 7 and goes to the end.
print(s[:]) #Starts from index 7 and goes to the end.
# Out:
# PROG
# MING
# PROGRAMMING

# %% [markdown]
# ---
#
# **Q83. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"`
#
# Extract:
# - Characters at every 2nd position starting from index 0 → `[::2]`
# - Characters at every 2nd position starting from index 1 → `[1::2]`
# - Characters at every 3rd position → `[::3]`

# %%
# Write your code here
s = "ABCDEFGHIJ"
print(s[::2])
print(s[1::2])
print(s[::3])
# Out:
# ACEGI
# BDFHJ
# ADGJ

# %% [markdown]
# ---
#
# **Q84. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Write slicing expressions to:
# - Reverse the entire string
# - Reverse only the first 4 characters

# %%
# Write your code here
s = "PYTHON"
print(s[::-1])
print(s[:4][::-1])
# Out:
# NOHTYP
# HTYP

# %% [markdown]
# ---
#
# **Q85. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"`
#
# Print:
# - The last 4 characters using **negative slicing** `[-4:]`
# - All except the last 3 characters `[:-3]`
# - Characters from index -6 to -2

# %%
# Write your code here
s = "ABCDEFGHIJ"
print(s[-4:])
print(s[:-3])
print(s[-6:-2])
# Out:
# GHIJ
# ABCDEFG
# EFGH

# %% [markdown]
# ---
#
# **Q86. 🔍 Predict the Output**
#
# ```python
# s = "DataScience"
# print(s[0:4])
# print(s[4:])
# print(s[:4])
# print(s[-7:-3])
# print(s[::2])
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
s = "DataScience"
print("line 1:",s[0:4])
print("line 2:",s[4:])
print("line 3:",s[:4])
print("line 4:",s[-7:-3])
print("line 5:",s[::2])
# Out:
# line 1: Data
# line 2: Science
# line 3: Data
# line 4: Scie
# line 5: DtSine

# %% [markdown]
# ---
#
# **Q87. 🖊️ Code Writing**
#
# `s = "Hello, World!"`
#
# Use slicing to extract:
# - `"Hello"`
# - `"World"`
# - `"World!"`

# %%
# Write your code here
s = "Hello, World!"
print(s[0:5])
print(s[7:12])
print(s[7:14])
# Out:
# Hello
# World
# World!

# %% [markdown]
# ---
#
# **Q88. 🖊️ Code Writing**
#
# `s = "PYTHON"`
#
# Write a slicing expression that returns an **empty string**.
# Add a comment explaining why it returns empty.

# %%
# Write your code here
s = "PYTHON"
print(s[3:3])   # Returns an empty string because the start and stop indexes are the same.

# %% [markdown]
# ---
#
# **Q89. 🖊️ Code Writing**
#
# `s = "0123456789"`
#
# Extract:
# - All **even-position digits** using `[::2]`
# - All **odd-position digits** using `[1::2]`

# %%
# Write your code here
s = "0123456789"
print(s[::2])
print(s[1::2])
# Out:
# 02468
# 13579

# %% [markdown]
# ---
#
# **Q90. 🖊️ Code Writing**
#
# `date = "25-12-2024"`
#
# Use slicing to extract:
# - Day: `"25"`
# - Month: `"12"`
# - Year: `"2024"`
#
# Print each with a label.

# %%
# Write your code here
date = "25-12-2024"
print("Date:",date[:2])
print("Month:",date[3:5])
print("Year:",date[6:10])
# Out:
# Date: 25
# Month: 12
# Year: 2024

# %% [markdown]
# ---
#
# **Q91. 🖊️ Code Writing**
#
# `email = "trainer@python.org"`
#
# Use slicing to extract:
# - The **username** (everything before `@`)
# - The **domain** (everything after `@`)
#
# *(Count characters to find the correct index)*

# %%
# Write your code here
email = "trainer@python.org"
print(email[0:7])
print(email[8:])
# Out:
# trainer
# python.org

# %% [markdown]
# ---
#
# **Q92. 🖊️ Code Writing**
#
# `s = "MADAM"`
#
# - Reverse the string using slicing
# - Check if the string equals its reverse
# - Print whether it is a palindrome

# %%
# Write your code here
s = "MADAM"
reserve=(s[::-1])
print("Palindrome:",s==reserve)
# Out:
# Palindrome: True

# %% [markdown]
# ---
#
# **Q93. 🖊️ Code Writing**
#
# `filename = "report_2024.xlsx"`
#
# Use slicing to:
# - Extract the file extension `"xlsx"` using **negative slicing**
# - Extract the filename without extension `"report_2024"`

# %%
# Write your code here
filename = "report_2024.xlsx"
print(filename[12:])
print(filename[0:11])
# Out:
# xlsx
# report_2024

# %% [markdown]
# ---
#
# **Q94. 🖊️ Code Writing**
#
# `emp_id = "EMP-HR-2024-001"`
#
# Use slicing to extract:
# - `"EMP"` (first 3 characters)
# - `"HR"` (department code)
# - `"2024"` (year)
# - `"001"` (employee number)

# %%
# Write your code here
emp_id = "EMP-HR-2024-001"
print(emp_id[0:3])
print(emp_id[4:6])
print(emp_id[7:11])
print(emp_id[12:])
# Out:
# EMP
# HR
# 2024
# 001

# %% [markdown]
# ---
#
# **Q95. 🖊️ Code Writing**
#
# `s = "ABCDEFGHIJ"`
#
# Write slicing expressions for:
# - Characters from index 2 to 8 with **step 2**
# - Characters from index 7 to 2 in **reverse** (step -1)
# - Characters from index 9 to 0 with **step -3**

# %%
# Write your code here
s = "ABCDEFGHIJ"
print(s[2:8:2])
print(s[7:2:-1])
print(s[9:0:-3])
# Out:
# CEG
# HGFED
# JGD

# %% [markdown]
# ---
#
# **Q96. 🖊️ Code Writing**
#
# `card = "1234567890123456"` (16-digit card number)
#
# Use slicing to:
# - Extract and print the **last 4 digits** (visible part)
# - Extract the **first 12 digits** (masked part)

# %%
# Write your code here
card = "1234567890123456"
print(card[-4:])
print(card[:12])
# Out:
# 3456
# 123456789012

# %% [markdown]
# ---
#
# **Q97. 🔍 Predict the Output**
#
# ```python
# s = "PYTHON"
# print(s[4:1:-1])
# print(s[::-2])
# print(s[-1:-4:-1])
# print(s[10:20])
# ```

# %%
# Write your expected output as comments below, then run to verify
# Expected Output:
# Line 1:
# Line 2:
# Line 3:
s = "PYTHON"
print("line 1:",s[4:1:-1])
print("line 2:",s[::-2])
print("line 3:",s[-1:-4:-1])
print("line 4:",s[10:20])
# Out:
# line 1: OHT
# line 2: NHY
# line 3: NOH
# line 4:

# %% [markdown]
# ---
#
# **Q98. 🖊️ Code Writing**
#
# `s = "H_e_l_l_o"`
#
# Use step slicing `[::2]` to extract only the letters.
# Print the result.

# %%
# Write your code here
s = "H_e_l_l_o"
print(s[::2])
# Out:
# Hello

# %% [markdown]
# ---
#
# **Q99. 🖊️ Code Writing**
#
# `s = "NOHTYP"`
#
# Use **reverse slicing** to convert it into `"PYTHON"`.
# Print the result.

# %%
# Write your code here
s = "NOHTYP"
print(s[::-1])
# Out:
# PYTHON

# %% [markdown]
# ---
#
# **Q100. 🖊️ Code Writing**
#
# `roll = "2024CSIT0087"`
#
# Use slicing to extract:
# - Admission Year: `"2024"` (index 0 to 4)
# - Branch: `"CSIT"` (index 4 to 8)
# - Student Number: `"0087"` (last 4 characters)
#
# Print each with a label.

# %%
# Write your code here
roll = "2024CSIT0087"
print("Admission Year:",roll[0:4])
print("Branch:",roll[4:8])
print("Student Name:",roll[-4:])
# Out:
# Admission Year: 2024
# Branch: CSIT
# Student Name: 0087

# %% [markdown]
# ---
# ---
# ## 🌍 Section 7: Scenario-Based Challenges
# ### *(10 Questions — 10 Code Writing)*

# %% [markdown]
# ---
#
# **Q101. 🖊️ Code Writing — OTP Extraction**
#
# `msg = "Your OTP is 847392. Do not share"
#
# The OTP is always at positions 12 to 18.
# Use slicing to extract and print the OTP.

# %%
# Write your code here
msg = "Your OTP is 847392. Do not share"
print(msg[12:18])
# Out:
# 847392

# %% [markdown]
# ---
#
# **Q102. 🖊️ Code Writing — Hashtag Removal**
#
# `tag = "#MachineLearning"`
#
# Use slicing to remove the `#` and print only `"MachineLearning"`.

# %%
# Write your code here
tag = "#MachineLearning"
print(tag[1:])
# Out:
# MachineLearning

# %% [markdown]
# ---
#
# **Q103. 🖊️ Code Writing — Reverse to Find Original**
#
# A prankster reversed a friend's name:
# `reversed_name = "avahB"`
#
# Use slicing to recover and print the original name.

# %%
# Write your code here
reversed_name = "avahB"
print("Original Name:",reversed_name[::-1])
# Out:
# Original Name: Bhava

# %% [markdown]
# ---
#
# **Q104. 🖊️ Code Writing — Barcode Country Code**
#
# `barcode = "8901030408947"`
#
# The first 3 digits are the country code (`890` = India).
# Use slicing to extract and print the country code.

# %%
# Write your code here
barcode = "8901030408947"
print("INDIA CODE:",barcode[:3])
# Out:
# INDIA CODE: 890

# %% [markdown]
# ---
#
# **Q105. 🖊️ Code Writing — Alternate Characters Pattern**
#
# `s = "AaBbCcDdEe"`
#
# Use step slicing to extract:
# - Only **uppercase** letters → `[::2]`
# - Only **lowercase** letters → `[1::2]`

# %%
# Write your code here
s = "AaBbCcDdEe"
print(s[::2])
print(s[1::2])
# Out:
# ABCDE
# abcde

# %% [markdown]
# ---
#
# **Q106. 🖊️ Code Writing — Mirror String**
#
# `s = "PYTHON"`
#
# Using **concatenation and slicing**, create and print the mirror string: `"PYTHONNOHTYP"`

# %%
# Write your code here
s = "PYTHON"
mirror=s+(s[::-1])
print(mirror)
# Out:
# PYTHONNOHTYP

# %% [markdown]
# ---
#
# **Q107. 🖊️ Code Writing — URL Cleanup**
#
# `url = "https://www.openai.com"`
#
# Use slicing to extract only `"openai"` from the URL.
# *(Hint: `https://www.` is 12 characters; `.com` is the last 4)*

# %%
# Write your code here
url = "https://www.openai.com"
print(url[12:-4])
# Out:
# openai

# %% [markdown]
# ---
#
# **Q108. 🖊️ Code Writing — Phone Number Formatting**
#
# `phone = "09876543210"`
#
# Use slicing to:
# - Remove the leading `0` and print the remaining 10 digits
# - Print the last 4 digits as a short caller ID

# %%
# Write your code here
phone = "09876543210"
print(phone[1:-1])
print(phone[-4:])
# Out:
# 987654321
# 3210

# %% [markdown]
# ---
#
# **Q109. 🖊️ Code Writing — Word Reversal Check**
#
# `word1 = "LISTEN"`
# `word2 = "NETSIL"`
#
# Use slicing to reverse `word1` and check if it equals `word2`.
# Print the boolean result.

# %%
# Write your code here
word1 = "LISTEN"
word2 = "NETSIL"
reverse=(word1[::-1])==word2
print(reverse)
# Out:
# True

# %% [markdown]
# ---
#
# **Q110. 🖊️ Code Writing — Secret Code Decoder**
#
# A secret message was encoded by reversing the text:
# `encoded = "!dlroW ,olleH"`
#
# Use slicing to decode and print the original message.

# %%
# Write your code here
encoded = "!dlroW ,olleH"
print(encoded[::-1])
# Out:
# Hello, World!
